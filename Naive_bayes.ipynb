# %%
from sklearn.model_selection import train_test_split
import os
import string
import numpy as np
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report

# %%
X = [] # an element of X is represented as (filename,text)
Y = [] # an element of Y represents the newsgroup category of the corresponding X element
for category in os.listdir('data/20_newsgroups')[0:4]:
    if category !='.DS_Store':
        for document in os.listdir('data/20_newsgroups/'+category) :
            print(category, document)
            with open('data/20_newsgroups/'+category+'/'+document, "r") as f:
                try:
                    X.append((document,f.read()))
                    Y.append(category)
                except:
                    continue
    else:
        continue
# Out:
# talk.politics.mideast 75895
# talk.politics.mideast 76248
# talk.politics.mideast 76277
# talk.politics.mideast 76045
# talk.politics.mideast 77197
# talk.politics.mideast 76421
# talk.politics.mideast 76283
# talk.politics.mideast 77351
# talk.politics.mideast 75406
# talk.politics.mideast 77369
# talk.politics.mideast 76089
# talk.politics.mideast 76419
# talk.politics.mideast 75892
# talk.politics.mideast 76284
# talk.politics.mideast 77356
# talk.politics.mideast 75401
# talk.politics.mideast 76426
# talk.politics.mideast 76042
# talk.politics.mideast 77190
# talk.politics.mideast 76270
# talk.politics.mideast 75408
# talk.politics.mideast 76279
# talk.politics.mideast 77199
# talk.politics.mideast 76080
# talk.politics.mideast 77360
# talk.politics.mideast 76074
# talk.politics.mideast 77394
# talk.politics.mideast 76246
# talk.politics.mideast 76410
# talk.politics.mideast 76428
# talk.politics.mideast 77358
# talk.politics.mideast 76417
# talk.politics.mideast 77393
# talk.politics.mideast 76241
# talk.politics.mideast 76073
# talk.politics.mideast 77367
# talk.politics.mideast 76087
# talk.politics.mideast 76443
# talk.politics.mideast 76027
# talk.politics.mideast 76215
# talk.politics.mideast 77333
# talk.politics.mideast 76018
# talk.politics.mideast 76488
# talk.politics.mideast 77334
# talk.politics.mideast 76212
# talk.politics.mideast 76020
# talk.politics.mideast 76444
# talk.politics.mideast 77302
# talk.politics.mideast 76486
# talk.politics.mideast 76472
# talk.politics.mideast 76224
# talk.politics.mideast 76016
# talk.politics.mideast 76029
# talk.politics.mideast 76011
# talk.politics.mideast 76223
# talk.politics.mideast 76475
# talk.politics.mideast 76481
# talk.politics.mideast 77305
# talk.politics.mideast 77359
# talk.politics.mideast 76429
# talk.politics.mideast 76086
# talk.politics.mideast 77366
# talk.politics.mideast 76416
# talk.politics.mideast 76072
# talk.politics.mideast 77392
# talk.politics.mideast 76240
# talk.politics.mideast 77198
# talk.politics.mideast 76278
# talk.politics.mideast 75409
# talk.politics.mideast 77395
# talk.politics.mideast 76247
# talk.politics.mideast 76075
# talk.politics.mideast 76411
# talk.politics.mideast 77361
# talk.politics.mideast 76081
# talk.politics.mideast 75893
# talk.politics.mideast 76418
# talk.politics.mideast 76088
# talk.politics.mideast 77368
# talk.politics.mideast 76427
# talk.politics.mideast 76271
# talk.politics.mideast 76043
# talk.politics.mideast 77191
# talk.politics.mideast 76285
# talk.politics.mideast 77357
# talk.politics.mideast 75400
# talk.politics.mideast 75894
# talk.politics.mideast 76249
# talk.politics.mideast 76282
# talk.politics.mideast 77350
# talk.politics.mideast 75407
# talk.politics.mideast 76044
# talk.politics.mideast 77196
# talk.politics.mideast 76276
# talk.politics.mideast 76420
# talk.politics.mideast 76480
# talk.politics.mideast 77304
# talk.politics.mideast 76222
# talk.politics.mideast 76010
# talk.politics.mideast 76474
# talk.politics.mideast 76473
# talk.politics.mideast 76017
# talk.politics.mideast 76225
# talk.politics.mideast 77303
# talk.politics.mideast 76487
# talk.politics.mideast 76028
# talk.politics.mideast 76021
# talk.politics.mideast 76213
# talk.politics.mideast 76445
# talk.politics.mideast 77335
# talk.politics.mideast 77332
# talk.politics.mideast 76442
# talk.politics.mideast 76214
# talk.politics.mideast 76026
# talk.politics.mideast 76489
# talk.politics.mideast 76019
# talk.politics.mideast 75984
# talk.politics.mideast 76359
# talk.politics.mideast 75970
# talk.politics.mideast 76366
# talk.politics.mideast 76154
# talk.politics.mideast 76530
# talk.politics.mideast 77240
# talk.politics.mideast 76392
# talk.politics.mideast 75379
# talk.politics.mideast 75977
# talk.politics.mideast 77278
# talk.politics.mideast 76198
# talk.politics.mideast 76508
# talk.politics.mideast 75983
# talk.politics.mideast 77247
# talk.politics.mideast 76395
# talk.politics.mideast 75948
# talk.politics.mideast 76537
# talk.politics.mideast 76153
# talk.politics.mideast 76361
# talk.politics.mideast 75941
# talk.politics.mideast 76368
# talk.politics.mideast 75370
# talk.politics.mideast 76191
# talk.politics.mideast 77271
# talk.politics.mideast 76165
# talk.politics.mideast 76357
# talk.politics.mideast 77285
# talk.politics.mideast 76501
# talk.politics.mideast 75384
# talk.politics.mideast 76539
# talk.politics.mideast 75946
# talk.politics.mideast 77249
# talk.politics.mideast 76506
# talk.politics.mideast 75383
# talk.politics.mideast 76350
# talk.politics.mideast 77282
# talk.politics.mideast 76162
# talk.politics.mideast 77276
# talk.politics.mideast 76196
# talk.politics.mideast 75377
# talk.politics.mideast 75979
# talk.politics.mideast 76552
# talk.politics.mideast 76136
# talk.politics.mideast 76304
# talk.politics.mideast 77222
# talk.politics.mideast 76109
# talk.politics.mideast 75912
# talk.politics.mideast 77813
# talk.politics.mideast 77225
# talk.politics.mideast 76303
# talk.politics.mideast 76131
# talk.politics.mideast 76555
# talk.politics.mideast 77814
# talk.politics.mideast 75915
# talk.politics.mideast 77213
# talk.politics.mideast 76563
# talk.politics.mideast 76335
# talk.politics.mideast 76107
# talk.politics.mideast 75923
# talk.politics.mideast 77822
# talk.politics.mideast 76138
# talk.politics.mideast 76100
# talk.politics.mideast 76332
# talk.politics.mideast 76564
# talk.politics.mideast 77214
# talk.politics.mideast 75924
# talk.politics.mideast 75947
# talk.politics.mideast 77248
# talk.politics.mideast 76538
# talk.politics.mideast 76197
# talk.politics.mideast 77277
# talk.politics.mideast 75978
# talk.politics.mideast 75376
# talk.politics.mideast 76507
# talk.politics.mideast 75382
# talk.politics.mideast 76163
# talk.politics.mideast 76351
# talk.politics.mideast 77283
# talk.politics.mideast 76369
# talk.politics.mideast 75940
# talk.politics.mideast 76356
# talk.politics.mideast 77284
# talk.politics.mideast 76164
# talk.politics.mideast 76500
# talk.politics.mideast 75385
# talk.politics.mideast 75371
# talk.politics.mideast 77270
# talk.politics.mideast 76190
# talk.politics.mideast 75982
# talk.politics.mideast 76509
# talk.politics.mideast 75976
# talk.politics.mideast 75378
# talk.politics.mideast 76199
# talk.politics.mideast 77279
# talk.politics.mideast 76536
# talk.politics.mideast 76360
# talk.politics.mideast 76152
# talk.politics.mideast 77246
# talk.politics.mideast 76394
# talk.politics.mideast 75949
# talk.politics.mideast 75971
# talk.politics.mideast 75985
# talk.politics.mideast 76358
# talk.politics.mideast 77241
# talk.politics.mideast 76393
# talk.politics.mideast 76155
# talk.politics.mideast 76367
# talk.politics.mideast 76531
# talk.politics.mideast 77215
# talk.politics.mideast 76333
# talk.politics.mideast 76101
# talk.politics.mideast 76565
# talk.politics.mideast 75925
# talk.politics.mideast 76562
# talk.politics.mideast 76106
# talk.politics.mideast 76334
# talk.politics.mideast 77212
# talk.politics.mideast 76139
# talk.politics.mideast 75922
# talk.politics.mideast 77823
# talk.politics.mideast 76130
# talk.politics.mideast 76302
# talk.politics.mideast 76554
# talk.politics.mideast 77224
# talk.politics.mideast 77815
# talk.politics.mideast 75914
# talk.politics.mideast 77223
# talk.politics.mideast 76553
# talk.politics.mideast 76305
# talk.politics.mideast 76137
# talk.politics.mideast 75913
# talk.politics.mideast 77812
# talk.politics.mideast 76108
# talk.politics.mideast 75931
# talk.politics.mideast 76318
# talk.politics.mideast 77201
# talk.politics.mideast 76115
# talk.politics.mideast 76327
# talk.politics.mideast 76549
# talk.politics.mideast 75936
# talk.politics.mideast 77239
# talk.politics.mideast 76320
# talk.politics.mideast 76112
# talk.politics.mideast 77206
# talk.politics.mideast 77808
# talk.politics.mideast 75909
# talk.politics.mideast 76329
# talk.politics.mideast 75900
# talk.politics.mideast 76316
# talk.politics.mideast 76124
# talk.politics.mideast 76540
# talk.politics.mideast 77230
# talk.politics.mideast 75907
# talk.politics.mideast 77208
# talk.politics.mideast 77806
# talk.politics.mideast 77237
# talk.politics.mideast 75938
# talk.politics.mideast 76547
# talk.politics.mideast 76123
# talk.politics.mideast 76311
# talk.politics.mideast 77263
# talk.politics.mideast 76183
# talk.politics.mideast 75396
# talk.politics.mideast 76513
# talk.politics.mideast 75998
# talk.politics.mideast 76345
# talk.politics.mideast 77297
# talk.politics.mideast 76177
# talk.politics.mideast 75953
# talk.politics.mideast 76148
# talk.politics.mideast 76170
# talk.politics.mideast 76342
# talk.politics.mideast 77290
# talk.politics.mideast 75391
# talk.politics.mideast 76514
# talk.politics.mideast 75365
# talk.politics.mideast 76184
# talk.politics.mideast 77264
# talk.politics.mideast 76389
# talk.politics.mideast 75954
# talk.politics.mideast 76522
# talk.politics.mideast 76146
# talk.politics.mideast 76374
# talk.politics.mideast 77252
# talk.politics.mideast 76380
# talk.politics.mideast 77299
# talk.politics.mideast 76179
# talk.politics.mideast 75398
# talk.politics.mideast 75996
# talk.politics.mideast 75962
# talk.politics.mideast 77255
# talk.politics.mideast 76387
# talk.politics.mideast 76373
# talk.politics.mideast 76141
# talk.politics.mideast 76525
# talk.politics.mideast 75965
# talk.politics.mideast 75991
# talk.politics.mideast 75906
# talk.politics.mideast 77807
# talk.politics.mideast 77209
# talk.politics.mideast 76546
# talk.politics.mideast 76310
# talk.politics.mideast 76122
# talk.politics.mideast 77236
# talk.politics.mideast 75939
# talk.politics.mideast 75901
# talk.politics.mideast 76328
# talk.politics.mideast 77231
# talk.politics.mideast 76125
# talk.politics.mideast 76317
# talk.politics.mideast 76541
# talk.politics.mideast 75937
# talk.politics.mideast 77238
# talk.politics.mideast 76548
# talk.politics.mideast 77809
# talk.politics.mideast 77207
# talk.politics.mideast 75908
# talk.politics.mideast 76113
# talk.politics.mideast 76321
# talk.politics.mideast 76319
# talk.politics.mideast 75930
# talk.politics.mideast 76326
# talk.politics.mideast 76114
# talk.politics.mideast 77200
# talk.politics.mideast 76140
# talk.politics.mideast 76372
# talk.politics.mideast 76524
# talk.politics.mideast 77254
# talk.politics.mideast 76386
# talk.politics.mideast 75990
# talk.politics.mideast 75964
# talk.politics.mideast 77253
# talk.politics.mideast 76381
# talk.politics.mideast 76523
# talk.politics.mideast 76375
# talk.politics.mideast 76147
# talk.politics.mideast 75963
# talk.politics.mideast 76178
# talk.politics.mideast 77298
# talk.politics.mideast 75997
# talk.politics.mideast 75399
# talk.politics.mideast 75364
# talk.politics.mideast 77265
# talk.politics.mideast 76185
# talk.politics.mideast 76343
# talk.politics.mideast 77291
# talk.politics.mideast 76171
# talk.politics.mideast 75390
# talk.politics.mideast 76515
# talk.politics.mideast 76388
# talk.politics.mideast 75955
# talk.politics.mideast 75999
# talk.politics.mideast 75397
# talk.politics.mideast 76512
# talk.politics.mideast 76176
# talk.politics.mideast 76344
# talk.politics.mideast 77296
# talk.politics.mideast 76182
# talk.politics.mideast 77262
# talk.politics.mideast 76149
# talk.politics.mideast 75952
# talk.politics.mideast 76209
# talk.politics.mideast 76494
# talk.politics.mideast 77310
# talk.politics.mideast 76004
# talk.politics.mideast 76236
# talk.politics.mideast 76460
# talk.politics.mideast 76458
# talk.politics.mideast 77328
# talk.politics.mideast 76467
# talk.politics.mideast 76231
# talk.politics.mideast 76003
# talk.politics.mideast 77317
# talk.politics.mideast 76493
# talk.politics.mideast 76238
# talk.politics.mideast 76207
# talk.politics.mideast 76035
# talk.politics.mideast 76451
# talk.politics.mideast 77321
# talk.politics.mideast 77319
# talk.politics.mideast 76469
# talk.politics.mideast 77326
# talk.politics.mideast 76456
# talk.politics.mideast 76032
# talk.politics.mideast 76200
# talk.politics.mideast 77372
# talk.politics.mideast 76092
# talk.politics.mideast 76402
# talk.politics.mideast 75889
# talk.politics.mideast 77386
# talk.politics.mideast 76254
# talk.politics.mideast 76066
# talk.politics.mideast 76059
# talk.politics.mideast 76061
# talk.politics.mideast 77381
# talk.politics.mideast 76253
# talk.politics.mideast 76405
# talk.politics.mideast 76095
# talk.politics.mideast 77375
# talk.politics.mideast 75422
# talk.politics.mideast 76298
# talk.politics.mideast 77178
# talk.politics.mideast 76433
# talk.politics.mideast 76057
# talk.politics.mideast 77185
# talk.politics.mideast 76265
# talk.politics.mideast 75414
# talk.politics.mideast 76291
# talk.politics.mideast 77343
# talk.politics.mideast 77388
# talk.politics.mideast 76068
# talk.politics.mideast 75887
# talk.politics.mideast 75873
# talk.politics.mideast 75413
# talk.politics.mideast 76296
# talk.politics.mideast 77344
# talk.politics.mideast 76262
# talk.politics.mideast 76050
# talk.politics.mideast 77182
# talk.politics.mideast 76434
# talk.politics.mideast 75874
# talk.politics.mideast 75880
# talk.politics.mideast 76468
# talk.politics.mideast 77318
# talk.politics.mideast 76457
# talk.politics.mideast 76201
# talk.politics.mideast 76033
# talk.politics.mideast 77327
# talk.politics.mideast 76239
# talk.politics.mideast 77320
# talk.politics.mideast 76034
# talk.politics.mideast 76206
# talk.politics.mideast 76450
# talk.politics.mideast 77329
# talk.politics.mideast 76459
# talk.politics.mideast 77316
# talk.politics.mideast 76492
# talk.politics.mideast 76466
# talk.politics.mideast 76002
# talk.politics.mideast 76230
# talk.politics.mideast 76208
# talk.politics.mideast 76237
# talk.politics.mideast 76005
# talk.politics.mideast 76461
# talk.politics.mideast 76495
# talk.politics.mideast 77311
# talk.politics.mideast 76051
# talk.politics.mideast 77183
# talk.politics.mideast 76263
# talk.politics.mideast 76435
# talk.politics.mideast 77177
# talk.politics.mideast 75412
# talk.politics.mideast 76297
# talk.politics.mideast 77345
# talk.politics.mideast 75881
# talk.politics.mideast 75875
# talk.politics.mideast 75415
# talk.politics.mideast 76290
# talk.politics.mideast 77342
# talk.politics.mideast 76432
# talk.politics.mideast 76264
# talk.politics.mideast 76056
# talk.politics.mideast 77184
# talk.politics.mideast 76069
# talk.politics.mideast 77389
# talk.politics.mideast 75886
# talk.politics.mideast 77374
# talk.politics.mideast 75423
# talk.politics.mideast 76094
# talk.politics.mideast 77380
# talk.politics.mideast 76252
# talk.politics.mideast 76060
# talk.politics.mideast 76404
# talk.politics.mideast 77179
# talk.politics.mideast 76299
# talk.politics.mideast 75888
# talk.politics.mideast 76403
# talk.politics.mideast 76067
# talk.politics.mideast 77387
# talk.politics.mideast 76255
# talk.politics.mideast 76093
# talk.politics.mideast 77373
# talk.politics.mideast 76058
# talk.politics.mideast 77337
# talk.politics.mideast 76023
# talk.politics.mideast 76211
# talk.politics.mideast 76447
# talk.politics.mideast 77308
# talk.politics.mideast 76478
# talk.politics.mideast 76440
# talk.politics.mideast 76216
# talk.politics.mideast 76024
# talk.politics.mideast 77330
# talk.politics.mideast 76229
# talk.politics.mideast 76220
# talk.politics.mideast 76012
# talk.politics.mideast 76476
# talk.politics.mideast 76482
# talk.politics.mideast 77306
# talk.politics.mideast 76449
# talk.politics.mideast 77339
# talk.politics.mideast 77301
# talk.politics.mideast 76485
# talk.politics.mideast 76471
# talk.politics.mideast 76015
# talk.politics.mideast 76227
# talk.politics.mideast 76218
# talk.politics.mideast 75891
# talk.politics.mideast 77355
# talk.politics.mideast 76287
# talk.politics.mideast 75402
# talk.politics.mideast 76425
# talk.politics.mideast 76273
# talk.politics.mideast 77193
# talk.politics.mideast 76041
# talk.politics.mideast 75896
# talk.politics.mideast 77399
# talk.politics.mideast 76079
# talk.politics.mideast 77194
# talk.politics.mideast 76046
# talk.politics.mideast 76274
# talk.politics.mideast 76422
# talk.politics.mideast 77352
# talk.politics.mideast 76280
# talk.politics.mideast 75405
# talk.politics.mideast 76289
# talk.politics.mideast 76414
# talk.politics.mideast 76070
# talk.politics.mideast 76242
# talk.politics.mideast 77390
# talk.politics.mideast 76084
# talk.politics.mideast 77364
# talk.politics.mideast 76048
# talk.politics.mideast 77363
# talk.politics.mideast 76083
# talk.politics.mideast 76245
# talk.politics.mideast 77397
# talk.politics.mideast 76077
# talk.politics.mideast 76413
# talk.politics.mideast 75898
# talk.politics.mideast 76470
# talk.politics.mideast 76226
# talk.politics.mideast 76014
# talk.politics.mideast 77300
# talk.politics.mideast 76484
# talk.politics.mideast 76219
# talk.politics.mideast 76483
# talk.politics.mideast 77307
# talk.politics.mideast 76013
# talk.politics.mideast 76221
# talk.politics.mideast 76477
# talk.politics.mideast 77338
# talk.politics.mideast 76448
# talk.politics.mideast 77331
# talk.politics.mideast 76441
# talk.politics.mideast 76025
# talk.politics.mideast 76217
# talk.politics.mideast 76228
# talk.politics.mideast 76210
# talk.politics.mideast 76022
# talk.politics.mideast 76446
# talk.politics.mideast 77336
# talk.politics.mideast 76479
# talk.politics.mideast 77309
# talk.politics.mideast 76049
# talk.politics.mideast 76076
# talk.politics.mideast 76244
# talk.politics.mideast 77396
# talk.politics.mideast 75899
# talk.politics.mideast 76412
# talk.politics.mideast 76082
# talk.politics.mideast 77362
# talk.politics.mideast 76288
# talk.politics.mideast 77365
# talk.politics.mideast 76085
# talk.politics.mideast 76415
# talk.politics.mideast 76243
# talk.politics.mideast 77391
# talk.politics.mideast 76071
# talk.politics.mideast 76078
# talk.politics.mideast 77398
# talk.politics.mideast 77353
# talk.politics.mideast 76281
# talk.politics.mideast 75404
# talk.politics.mideast 76275
# talk.politics.mideast 77195
# talk.politics.mideast 76047
# talk.politics.mideast 76423
# talk.politics.mideast 75890
# talk.politics.mideast 76424
# talk.politics.mideast 77192
# talk.politics.mideast 76040
# talk.politics.mideast 76272
# talk.politics.mideast 77354
# talk.politics.mideast 76286
# talk.politics.mideast 75403
# talk.politics.mideast 75929
# talk.politics.mideast 77226
# talk.politics.mideast 76132
# talk.politics.mideast 76300
# talk.politics.mideast 76556
# talk.politics.mideast 77219
# talk.politics.mideast 77817
# talk.politics.mideast 75916
# talk.politics.mideast 76569
# talk.politics.mideast 76551
# talk.politics.mideast 76307
# talk.politics.mideast 76135
# talk.politics.mideast 77221
# talk.politics.mideast 76338
# talk.politics.mideast 75911
# talk.politics.mideast 77810
# talk.politics.mideast 76331
# talk.politics.mideast 76103
# talk.politics.mideast 76567
# talk.politics.mideast 75918
# talk.politics.mideast 77217
# talk.politics.mideast 77819
# talk.politics.mideast 76558
# talk.politics.mideast 77228
# talk.politics.mideast 75927
# talk.politics.mideast 77210
# talk.politics.mideast 76560
# talk.politics.mideast 76104
# talk.politics.mideast 76336
# talk.politics.mideast 75920
# talk.politics.mideast 77821
# talk.politics.mideast 76309
# talk.politics.mideast 75974
# talk.politics.mideast 75980
# talk.politics.mideast 76396
# talk.politics.mideast 77244
# talk.politics.mideast 76534
# talk.politics.mideast 76362
# talk.politics.mideast 76150
# talk.politics.mideast 75389
# talk.politics.mideast 75987
# talk.politics.mideast 77288
# talk.politics.mideast 76168
# talk.politics.mideast 75973
# talk.politics.mideast 76157
# talk.politics.mideast 76365
# talk.politics.mideast 76533
# talk.politics.mideast 76391
# talk.politics.mideast 77243
# talk.politics.mideast 75945
# talk.politics.mideast 76398
# talk.politics.mideast 76505
# talk.politics.mideast 76161
# talk.politics.mideast 77281
# talk.politics.mideast 76353
# talk.politics.mideast 76195
# talk.politics.mideast 77275
# talk.politics.mideast 75374
# talk.politics.mideast 75942
# talk.politics.mideast 76159
# talk.politics.mideast 75373
# talk.politics.mideast 77272
# talk.politics.mideast 76192
# talk.politics.mideast 77286
# talk.politics.mideast 76354
# talk.politics.mideast 76166
# talk.politics.mideast 76502
# talk.politics.mideast 75387
# talk.politics.mideast 75989
# talk.politics.mideast 76561
# talk.politics.mideast 76337
# talk.politics.mideast 76105
# talk.politics.mideast 77211
# talk.politics.mideast 76308
# talk.politics.mideast 75921
# talk.politics.mideast 77820
# talk.politics.mideast 75919
# talk.politics.mideast 77818
# talk.politics.mideast 77216
# talk.politics.mideast 76102
# talk.politics.mideast 76330
# talk.politics.mideast 76566
# talk.politics.mideast 77229
# talk.politics.mideast 75926
# talk.politics.mideast 76559
# talk.politics.mideast 77220
# talk.politics.mideast 76550
# talk.politics.mideast 76134
# talk.politics.mideast 76306
# talk.politics.mideast 75910
# talk.politics.mideast 77811
# talk.politics.mideast 76339
# talk.politics.mideast 76301
# talk.politics.mideast 76133
# talk.politics.mideast 76557
# talk.politics.mideast 75928
# talk.politics.mideast 77227
# talk.politics.mideast 76568
# talk.politics.mideast 77816
# talk.politics.mideast 77218
# talk.politics.mideast 75917
# talk.politics.mideast 76158
# talk.politics.mideast 75943
# talk.politics.mideast 76167
# talk.politics.mideast 77287
# talk.politics.mideast 76355
# talk.politics.mideast 75988
# talk.politics.mideast 76503
# talk.politics.mideast 75386
# talk.politics.mideast 75372
# talk.politics.mideast 76193
# talk.politics.mideast 77273
# talk.politics.mideast 75944
# talk.politics.mideast 76399
# talk.politics.mideast 77274
# talk.politics.mideast 76194
# talk.politics.mideast 75375
# talk.politics.mideast 76504
# talk.politics.mideast 75381
# talk.politics.mideast 77280
# talk.politics.mideast 76352
# talk.politics.mideast 76160
# talk.politics.mideast 75972
# talk.politics.mideast 75986
# talk.politics.mideast 75388
# talk.politics.mideast 76169
# talk.politics.mideast 77289
# talk.politics.mideast 76390
# talk.politics.mideast 77242
# talk.politics.mideast 76364
# talk.politics.mideast 76156
# talk.politics.mideast 76532
# talk.politics.mideast 75981
# talk.politics.mideast 75975
# talk.politics.mideast 76535
# talk.politics.mideast 76363
# talk.politics.mideast 76397
# talk.politics.mideast 77245
# talk.politics.mideast 77293
# talk.politics.mideast 76341
# talk.politics.mideast 76173
# talk.politics.mideast 75392
# talk.politics.mideast 76517
# talk.politics.mideast 75366
# talk.politics.mideast 75968
# talk.politics.mideast 77267
# talk.politics.mideast 76187
# talk.politics.mideast 76528
# talk.politics.mideast 77258
# talk.politics.mideast 75957
# talk.politics.mideast 76180
# talk.politics.mideast 77260
# talk.politics.mideast 75395
# talk.politics.mideast 76510
# talk.politics.mideast 76174
# talk.politics.mideast 77294
# talk.politics.mideast 76346
# talk.politics.mideast 75950
# talk.politics.mideast 76379
# talk.politics.mideast 75959
# talk.politics.mideast 77400
# talk.politics.mideast 76384
# talk.politics.mideast 77256
# talk.politics.mideast 76142
# talk.politics.mideast 76370
# talk.politics.mideast 76526
# talk.politics.mideast 77269
# talk.politics.mideast 76189
# talk.politics.mideast 75966
# talk.politics.mideast 76519
# talk.politics.mideast 75992
# talk.politics.mideast 76521
# talk.politics.mideast 76377
# talk.politics.mideast 76145
# talk.politics.mideast 76383
# talk.politics.mideast 77251
# talk.politics.mideast 76348
# talk.politics.mideast 75995
# talk.politics.mideast 75961
# talk.politics.mideast 75935
# talk.politics.mideast 76111
# talk.politics.mideast 76323
# talk.politics.mideast 77205
# talk.politics.mideast 75932
# talk.politics.mideast 76129
# talk.politics.mideast 77202
# talk.politics.mideast 76324
# talk.politics.mideast 76116
# talk.politics.mideast 75904
# talk.politics.mideast 77805
# talk.politics.mideast 77234
# talk.politics.mideast 76544
# talk.politics.mideast 76312
# talk.politics.mideast 76120
# talk.politics.mideast 76118
# talk.politics.mideast 75903
# talk.politics.mideast 76127
# talk.politics.mideast 76315
# talk.politics.mideast 76543
# talk.politics.mideast 77233
# talk.politics.mideast 76382
# talk.politics.mideast 77250
# talk.politics.mideast 76520
# talk.politics.mideast 76144
# talk.politics.mideast 76376
# talk.politics.mideast 75960
# talk.politics.mideast 76349
# talk.politics.mideast 75994
# talk.politics.mideast 76371
# talk.politics.mideast 76143
# talk.politics.mideast 76527
# talk.politics.mideast 77401
# talk.politics.mideast 75958
# talk.politics.mideast 76385
# talk.politics.mideast 77257
# talk.politics.mideast 75993
# talk.politics.mideast 76518
# talk.politics.mideast 76188
# talk.politics.mideast 77268
# talk.politics.mideast 75967
# talk.politics.mideast 75369
# talk.politics.mideast 75394
# talk.politics.mideast 76511
# talk.politics.mideast 77295
# talk.politics.mideast 76347
# talk.politics.mideast 76175
# talk.politics.mideast 77261
# talk.politics.mideast 76181
# talk.politics.mideast 76378
# talk.politics.mideast 75951
# talk.politics.mideast 77850
# talk.politics.mideast 75969
# talk.politics.mideast 75367
# talk.politics.mideast 76186
# talk.politics.mideast 77266
# talk.politics.mideast 76172
# talk.politics.mideast 77292
# talk.politics.mideast 76340
# talk.politics.mideast 75393
# talk.politics.mideast 76516
# talk.politics.mideast 77259
# talk.politics.mideast 75956
# talk.politics.mideast 76529
# talk.politics.mideast 77803
# talk.politics.mideast 75902
# talk.politics.mideast 76119
# talk.politics.mideast 77232
# talk.politics.mideast 76314
# talk.politics.mideast 76126
# talk.politics.mideast 76542
# talk.politics.mideast 75905
# talk.politics.mideast 77804
# talk.politics.mideast 76545
# talk.politics.mideast 76121
# talk.politics.mideast 76313
# talk.politics.mideast 77235
# talk.politics.mideast 76128
# talk.politics.mideast 75933
# talk.politics.mideast 76117
# talk.politics.mideast 76325
# talk.politics.mideast 77203
# talk.politics.mideast 75934
# talk.politics.mideast 77204
# talk.politics.mideast 76322
# talk.politics.mideast 76110
# talk.politics.mideast 76250
# talk.politics.mideast 77382
# talk.politics.mideast 76062
# talk.politics.mideast 76406
# talk.politics.mideast 75879
# talk.politics.mideast 77376
# talk.politics.mideast 75421
# talk.politics.mideast 76096
# talk.politics.mideast 76439
# talk.politics.mideast 77349
# talk.politics.mideast 76091
# talk.politics.mideast 77371
# talk.politics.mideast 76401
# talk.politics.mideast 76065
# talk.politics.mideast 76257
# talk.politics.mideast 77385
# talk.politics.mideast 75419
# talk.politics.mideast 76268
# talk.politics.mideast 77188
# talk.politics.mideast 75410
# talk.politics.mideast 77347
# talk.politics.mideast 76295
# talk.politics.mideast 77181
# talk.politics.mideast 76053
# talk.politics.mideast 76261
# talk.politics.mideast 76437
# talk.politics.mideast 77378
# talk.politics.mideast 76098
# talk.politics.mideast 75877
# talk.politics.mideast 76408
# talk.politics.mideast 75883
# talk.politics.mideast 76430
# talk.politics.mideast 76266
# talk.politics.mideast 77186
# talk.politics.mideast 76054
# talk.politics.mideast 75417
# talk.politics.mideast 77340
# talk.politics.mideast 76292
# talk.politics.mideast 76259
# talk.politics.mideast 75884
# talk.politics.mideast 76464
# talk.politics.mideast 76000
# talk.politics.mideast 76232
# talk.politics.mideast 77314
# talk.politics.mideast 76490
# talk.politics.mideast 76038
# talk.politics.mideast 76497
# talk.politics.mideast 77313
# talk.politics.mideast 76235
# talk.politics.mideast 76007
# talk.politics.mideast 76463
# talk.politics.mideast 77325
# talk.politics.mideast 76455
# talk.politics.mideast 76203
# talk.politics.mideast 76031
# talk.politics.mideast 76009
# talk.politics.mideast 76499
# talk.politics.mideast 76036
# talk.politics.mideast 76204
# talk.politics.mideast 76452
# talk.politics.mideast 77322
# talk.politics.mideast 75416
# talk.politics.mideast 77341
# talk.politics.mideast 76293
# talk.politics.mideast 76431
# talk.politics.mideast 77187
# talk.politics.mideast 76055
# talk.politics.mideast 76267
# talk.politics.mideast 76258
# talk.politics.mideast 75885
# talk.politics.mideast 76260
# talk.politics.mideast 77180
# talk.politics.mideast 76052
# talk.politics.mideast 76436
# talk.politics.mideast 75411
# talk.politics.mideast 77346
# talk.politics.mideast 76294
# talk.politics.mideast 75882
# talk.politics.mideast 76409
# talk.politics.mideast 76099
# talk.politics.mideast 77379
# talk.politics.mideast 75876
# talk.politics.mideast 76400
# talk.politics.mideast 76256
# talk.politics.mideast 77384
# talk.politics.mideast 76064
# talk.politics.mideast 77370
# talk.politics.mideast 76090
# talk.politics.mideast 77189
# talk.politics.mideast 76269
# talk.politics.mideast 75418
# talk.politics.mideast 75878
# talk.politics.mideast 76097
# talk.politics.mideast 77377
# talk.politics.mideast 75420
# talk.politics.mideast 76063
# talk.politics.mideast 76251
# talk.politics.mideast 77383
# talk.politics.mideast 76407
# talk.politics.mideast 77348
# talk.politics.mideast 76438
# talk.politics.mideast 76498
# talk.politics.mideast 76008
# talk.politics.mideast 77323
# talk.politics.mideast 76205
# talk.politics.mideast 76037
# talk.politics.mideast 76453
# talk.politics.mideast 76454
# talk.politics.mideast 76030
# talk.politics.mideast 76202
# talk.politics.mideast 77324
# talk.politics.mideast 76039
# talk.politics.mideast 76006
# talk.politics.mideast 76234
# talk.politics.mideast 76462
# talk.politics.mideast 76496
# talk.politics.mideast 77312
# talk.politics.mideast 77315
# talk.politics.mideast 76491
# talk.politics.mideast 76465
# talk.politics.mideast 76233
# talk.politics.mideast 76001
# rec.autos 103084
# rec.autos 103414
# rec.autos 103070
# rec.autos 103242
# rec.autos 102955
# rec.autos 102999
# rec.autos 103077
# rec.autos 103413
# rec.autos 103083
# rec.autos 103048
# rec.autos 102952
# rec.autos 102738
# rec.autos 103425
# rec.autos 103041
# rec.autos 102990
# rec.autos 102964
# rec.autos 102736
# rec.autos 103280
# rec.autos 103046
# rec.autos 103422
# rec.autos 102963
# rec.autos 102997
# rec.autos 103079
# rec.autos 102937
# rec.autos 103449
# rec.autos 103811
# rec.autos 102762
# rec.autos 101583
# rec.autos 102908
# rec.autos 103220
# rec.autos 101577
# rec.autos 103012
# rec.autos 102796
# rec.autos 103218
# rec.autos 103688
# rec.autos 102930
# rec.autos 102791
# rec.autos 103015
# rec.autos 103227
# rec.autos 101570
# rec.autos 101584
# rec.autos 102765
# rec.autos 102798
# rec.autos 101579
# rec.autos 102906
# rec.autos 103023
# rec.autos 103211
# rec.autos 103675
# rec.autos 103447
# rec.autos 103681
# rec.autos 102753
# rec.autos 102939
# rec.autos 102901
# rec.autos 103229
# rec.autos 103686
# rec.autos 102754
# rec.autos 103440
# rec.autos 103672
# rec.autos 103216
# rec.autos 103024
# rec.autos 103047
# rec.autos 103423
# rec.autos 102737
# rec.autos 103281
# rec.autos 103078
# rec.autos 102996
# rec.autos 102962
# rec.autos 103424
# rec.autos 103040
# rec.autos 102965
# rec.autos 102991
# rec.autos 103082
# rec.autos 103076
# rec.autos 102998
# rec.autos 103244
# rec.autos 103412
# rec.autos 102953
# rec.autos 102739
# rec.autos 103049
# rec.autos 103415
# rec.autos 103243
# rec.autos 103071
# rec.autos 103085
# rec.autos 102954
# rec.autos 103228
# rec.autos 102900
# rec.autos 103673
# rec.autos 103441
# rec.autos 103025
# rec.autos 103217
# rec.autos 103687
# rec.autos 102755
# rec.autos 102907
# rec.autos 102799
# rec.autos 101578
# rec.autos 103680
# rec.autos 102752
# rec.autos 102938
# rec.autos 103210
# rec.autos 103022
# rec.autos 103446
# rec.autos 103674
# rec.autos 103689
# rec.autos 102931
# rec.autos 103219
# rec.autos 101585
# rec.autos 103484
# rec.autos 102764
# rec.autos 102790
# rec.autos 103226
# rec.autos 101571
# rec.autos 103014
# rec.autos 103448
# rec.autos 103810
# rec.autos 102936
# rec.autos 103013
# rec.autos 103221
# rec.autos 101576
# rec.autos 102797
# rec.autos 102763
# rec.autos 102909
# rec.autos 101582
# rec.autos 103195
# rec.autos 103737
# rec.autos 103505
# rec.autos 101636
# rec.autos 103161
# rec.autos 103353
# rec.autos 102844
# rec.autos 101609
# rec.autos 103708
# rec.autos 103354
# rec.autos 101631
# rec.autos 103166
# rec.autos 102888
# rec.autos 103502
# rec.autos 103192
# rec.autos 103159
# rec.autos 102843
# rec.autos 103706
# rec.autos 103362
# rec.autos 103150
# rec.autos 101607
# rec.autos 101638
# rec.autos 102881
# rec.autos 103739
# rec.autos 102875
# rec.autos 103157
# rec.autos 101600
# rec.autos 103701
# rec.autos 102872
# rec.autos 103168
# rec.autos 102886
# rec.autos 102826
# rec.autos 102819
# rec.autos 103331
# rec.autos 101654
# rec.autos 103103
# rec.autos 103755
# rec.autos 103309
# rec.autos 102821
# rec.autos 103752
# rec.autos 101653
# rec.autos 103104
# rec.autos 103336
# rec.autos 102817
# rec.autos 103132
# rec.autos 101665
# rec.autos 103300
# rec.autos 103764
# rec.autos 102828
# rec.autos 102810
# rec.autos 103338
# rec.autos 103763
# rec.autos 103307
# rec.autos 103135
# rec.autos 101662
# rec.autos 103156
# rec.autos 101601
# rec.autos 103532
# rec.autos 103700
# rec.autos 102887
# rec.autos 103169
# rec.autos 102873
# rec.autos 103707
# rec.autos 103151
# rec.autos 101606
# rec.autos 102874
# rec.autos 101639
# rec.autos 102880
# rec.autos 103738
# rec.autos 103193
# rec.autos 101630
# rec.autos 102889
# rec.autos 103167
# rec.autos 103731
# rec.autos 103503
# rec.autos 102842
# rec.autos 103158
# rec.autos 103504
# rec.autos 103736
# rec.autos 103352
# rec.autos 101637
# rec.autos 103160
# rec.autos 103194
# rec.autos 101608
# rec.autos 103709
# rec.autos 102845
# rec.autos 103339
# rec.autos 102811
# rec.autos 103762
# rec.autos 103134
# rec.autos 101663
# rec.autos 103306
# rec.autos 102816
# rec.autos 102829
# rec.autos 103301
# rec.autos 103133
# rec.autos 101664
# rec.autos 103765
# rec.autos 102820
# rec.autos 103308
# rec.autos 103753
# rec.autos 103337
# rec.autos 101652
# rec.autos 103105
# rec.autos 102827
# rec.autos 101655
# rec.autos 103102
# rec.autos 103330
# rec.autos 103754
# rec.autos 102818
# rec.autos 103776
# rec.autos 103312
# rec.autos 101677
# rec.autos 103120
# rec.autos 101648
# rec.autos 103749
# rec.autos 102805
# rec.autos 101670
# rec.autos 103127
# rec.autos 103315
# rec.autos 103771
# rec.autos 102802
# rec.autos 103118
# rec.autos 103747
# rec.autos 103111
# rec.autos 101646
# rec.autos 103323
# rec.autos 102834
# rec.autos 101679
# rec.autos 103778
# rec.autos 103116
# rec.autos 101641
# rec.autos 103740
# rec.autos 103129
# rec.autos 102833
# rec.autos 103519
# rec.autos 102893
# rec.autos 102867
# rec.autos 103189
# rec.autos 101615
# rec.autos 103142
# rec.autos 103370
# rec.autos 103714
# rec.autos 103526
# rec.autos 102858
# rec.autos 103384
# rec.autos 102860
# rec.autos 102894
# rec.autos 103348
# rec.autos 103383
# rec.autos 103521
# rec.autos 103713
# rec.autos 103377
# rec.autos 101612
# rec.autos 103145
# rec.autos 102856
# rec.autos 103528
# rec.autos 102869
# rec.autos 103187
# rec.autos 103341
# rec.autos 103173
# rec.autos 101624
# rec.autos 103517
# rec.autos 103725
# rec.autos 103379
# rec.autos 102851
# rec.autos 103722
# rec.autos 103510
# rec.autos 103174
# rec.autos 101623
# rec.autos 103346
# rec.autos 103180
# rec.autos 103117
# rec.autos 101640
# rec.autos 103325
# rec.autos 103741
# rec.autos 102832
# rec.autos 103128
# rec.autos 103746
# rec.autos 103322
# rec.autos 103110
# rec.autos 101647
# rec.autos 101678
# rec.autos 103779
# rec.autos 102835
# rec.autos 103314
# rec.autos 101671
# rec.autos 103126
# rec.autos 103770
# rec.autos 103119
# rec.autos 102803
# rec.autos 103777
# rec.autos 101676
# rec.autos 103121
# rec.autos 103313
# rec.autos 102804
# rec.autos 103748
# rec.autos 102850
# rec.autos 103378
# rec.autos 103181
# rec.autos 103511
# rec.autos 103723
# rec.autos 103347
# rec.autos 103175
# rec.autos 101622
# rec.autos 103529
# rec.autos 102857
# rec.autos 103172
# rec.autos 101625
# rec.autos 103340
# rec.autos 103724
# rec.autos 103516
# rec.autos 103186
# rec.autos 102868
# rec.autos 103349
# rec.autos 102895
# rec.autos 102861
# rec.autos 103712
# rec.autos 103520
# rec.autos 101613
# rec.autos 103144
# rec.autos 103376
# rec.autos 103382
# rec.autos 103188
# rec.autos 102866
# rec.autos 103518
# rec.autos 102892
# rec.autos 103385
# rec.autos 102859
# rec.autos 103371
# rec.autos 101614
# rec.autos 103143
# rec.autos 103527
# rec.autos 103715
# rec.autos 103455
# rec.autos 103667
# rec.autos 103203
# rec.autos 101554
# rec.autos 103031
# rec.autos 103693
# rec.autos 102741
# rec.autos 103658
# rec.autos 102914
# rec.autos 103694
# rec.autos 102746
# rec.autos 103036
# rec.autos 103204
# rec.autos 101553
# rec.autos 103660
# rec.autos 103452
# rec.autos 101598
# rec.autos 102913
# rec.autos 103499
# rec.autos 102779
# rec.autos 103009
# rec.autos 101591
# rec.autos 102770
# rec.autos 102784
# rec.autos 103656
# rec.autos 103000
# rec.autos 101565
# rec.autos 103232
# rec.autos 102925
# rec.autos 103803
# rec.autos 103669
# rec.autos 101562
# rec.autos 103235
# rec.autos 103007
# rec.autos 102783
# rec.autos 103497
# rec.autos 102777
# rec.autos 101596
# rec.autos 103804
# rec.autos 103038
# rec.autos 102922
# rec.autos 102748
# rec.autos 103408
# rec.autos 102982
# rec.autos 103098
# rec.autos 102976
# rec.autos 103053
# rec.autos 103261
# rec.autos 103437
# rec.autos 102949
# rec.autos 103295
# rec.autos 102971
# rec.autos 102985
# rec.autos 103259
# rec.autos 103292
# rec.autos 103430
# rec.autos 103266
# rec.autos 103054
# rec.autos 102947
# rec.autos 103895
# rec.autos 103439
# rec.autos 103096
# rec.autos 102978
# rec.autos 103062
# rec.autos 103406
# rec.autos 103268
# rec.autos 102940
# rec.autos 103065
# rec.autos 103257
# rec.autos 103091
# rec.autos 102776
# rec.autos 103496
# rec.autos 101597
# rec.autos 103006
# rec.autos 101563
# rec.autos 103234
# rec.autos 102782
# rec.autos 103650
# rec.autos 102923
# rec.autos 102749
# rec.autos 103039
# rec.autos 103805
# rec.autos 102785
# rec.autos 103657
# rec.autos 101564
# rec.autos 103233
# rec.autos 103001
# rec.autos 101590
# rec.autos 103491
# rec.autos 102771
# rec.autos 103802
# rec.autos 103668
# rec.autos 102924
# rec.autos 103205
# rec.autos 101552
# rec.autos 103037
# rec.autos 103453
# rec.autos 103661
# rec.autos 103695
# rec.autos 102747
# rec.autos 103008
# rec.autos 102912
# rec.autos 101599
# rec.autos 102778
# rec.autos 103498
# rec.autos 103692
# rec.autos 102740
# rec.autos 103666
# rec.autos 103454
# rec.autos 103030
# rec.autos 103202
# rec.autos 101555
# rec.autos 102915
# rec.autos 103659
# rec.autos 102941
# rec.autos 103269
# rec.autos 103090
# rec.autos 103256
# rec.autos 103064
# rec.autos 103438
# rec.autos 102946
# rec.autos 103063
# rec.autos 103251
# rec.autos 103407
# rec.autos 102979
# rec.autos 103097
# rec.autos 103258
# rec.autos 102984
# rec.autos 102970
# rec.autos 103431
# rec.autos 103055
# rec.autos 103267
# rec.autos 103293
# rec.autos 102977
# rec.autos 103099
# rec.autos 103409
# rec.autos 102983
# rec.autos 103294
# rec.autos 102948
# rec.autos 103260
# rec.autos 103052
# rec.autos 103436
# rec.autos 103029
# rec.autos 103815
# rec.autos 102759
# rec.autos 102933
# rec.autos 102792
# rec.autos 103224
# rec.autos 101573
# rec.autos 103016
# rec.autos 101587
# rec.autos 102766
# rec.autos 102934
# rec.autos 103678
# rec.autos 103812
# rec.autos 102761
# rec.autos 101580
# rec.autos 103011
# rec.autos 103223
# rec.autos 101574
# rec.autos 103647
# rec.autos 102795
# rec.autos 103475
# rec.autos 102768
# rec.autos 101589
# rec.autos 102902
# rec.autos 103018
# rec.autos 102757
# rec.autos 103685
# rec.autos 103671
# rec.autos 103443
# rec.autos 103027
# rec.autos 103215
# rec.autos 102905
# rec.autos 103212
# rec.autos 103020
# rec.autos 103444
# rec.autos 103676
# rec.autos 102750
# rec.autos 103682
# rec.autos 103074
# rec.autos 103410
# rec.autos 103080
# rec.autos 103279
# rec.autos 102951
# rec.autos 102969
# rec.autos 103087
# rec.autos 103417
# rec.autos 103241
# rec.autos 103073
# rec.autos 102956
# rec.autos 103428
# rec.autos 102735
# rec.autos 103283
# rec.autos 103045
# rec.autos 103421
# rec.autos 102960
# rec.autos 102994
# rec.autos 103426
# rec.autos 103042
# rec.autos 103270
# rec.autos 102958
# rec.autos 103284
# rec.autos 102732
# rec.autos 102993
# rec.autos 103419
# rec.autos 102967
# rec.autos 103089
# rec.autos 102904
# rec.autos 102751
# rec.autos 103683
# rec.autos 103021
# rec.autos 103213
# rec.autos 103677
# rec.autos 103445
# rec.autos 103019
# rec.autos 102769
# rec.autos 102903
# rec.autos 101588
# rec.autos 103442
# rec.autos 103670
# rec.autos 103214
# rec.autos 103026
# rec.autos 102756
# rec.autos 103684
# rec.autos 103679
# rec.autos 103813
# rec.autos 102935
# rec.autos 103222
# rec.autos 101575
# rec.autos 103010
# rec.autos 103474
# rec.autos 102794
# rec.autos 102760
# rec.autos 101581
# rec.autos 102758
# rec.autos 102932
# rec.autos 103814
# rec.autos 103028
# rec.autos 101586
# rec.autos 102767
# rec.autos 102793
# rec.autos 103017
# rec.autos 103225
# rec.autos 101572
# rec.autos 102959
# rec.autos 102733
# rec.autos 103427
# rec.autos 103043
# rec.autos 103088
# rec.autos 102966
# rec.autos 102992
# rec.autos 103418
# rec.autos 103044
# rec.autos 103420
# rec.autos 102734
# rec.autos 103282
# rec.autos 102995
# rec.autos 102961
# rec.autos 103416
# rec.autos 103072
# rec.autos 103240
# rec.autos 103086
# rec.autos 102968
# rec.autos 103429
# rec.autos 102957
# rec.autos 103081
# rec.autos 103075
# rec.autos 103411
# rec.autos 102950
# rec.autos 103278
# rec.autos 103138
# rec.autos 102822
# rec.autos 103751
# rec.autos 103335
# rec.autos 101650
# rec.autos 103107
# rec.autos 102825
# rec.autos 103769
# rec.autos 101668
# rec.autos 101657
# rec.autos 103100
# rec.autos 103332
# rec.autos 103756
# rec.autos 102813
# rec.autos 103109
# rec.autos 103760
# rec.autos 103136
# rec.autos 101661
# rec.autos 103304
# rec.autos 103758
# rec.autos 101659
# rec.autos 102814
# rec.autos 103303
# rec.autos 103131
# rec.autos 101666
# rec.autos 103767
# rec.autos 101632
# rec.autos 103165
# rec.autos 103733
# rec.autos 103501
# rec.autos 103191
# rec.autos 103368
# rec.autos 102840
# rec.autos 103196
# rec.autos 102878
# rec.autos 103506
# rec.autos 103734
# rec.autos 103350
# rec.autos 101635
# rec.autos 103162
# rec.autos 102847
# rec.autos 103366
# rec.autos 103154
# rec.autos 101603
# rec.autos 103530
# rec.autos 103702
# rec.autos 102871
# rec.autos 102885
# rec.autos 103705
# rec.autos 103153
# rec.autos 101604
# rec.autos 103361
# rec.autos 102849
# rec.autos 102882
# rec.autos 103508
# rec.autos 103198
# rec.autos 102876
# rec.autos 102815
# rec.autos 101658
# rec.autos 103130
# rec.autos 101667
# rec.autos 103302
# rec.autos 103766
# rec.autos 103108
# rec.autos 102812
# rec.autos 103761
# rec.autos 103137
# rec.autos 101660
# rec.autos 103768
# rec.autos 101669
# rec.autos 102824
# rec.autos 103333
# rec.autos 101656
# rec.autos 103101
# rec.autos 103757
# rec.autos 102823
# rec.autos 103139
# rec.autos 103750
# rec.autos 101651
# rec.autos 103106
# rec.autos 103334
# rec.autos 102848
# rec.autos 103536
# rec.autos 103704
# rec.autos 103152
# rec.autos 101605
# rec.autos 102877
# rec.autos 103199
# rec.autos 102883
# rec.autos 103509
# rec.autos 103155
# rec.autos 101602
# rec.autos 103367
# rec.autos 103703
# rec.autos 103531
# rec.autos 102884
# rec.autos 102870
# rec.autos 103735
# rec.autos 103507
# rec.autos 101634
# rec.autos 103163
# rec.autos 103351
# rec.autos 102879
# rec.autos 103197
# rec.autos 102846
# rec.autos 103190
# rec.autos 101633
# rec.autos 103164
# rec.autos 103500
# rec.autos 103732
# rec.autos 102841
# rec.autos 103369
# rec.autos 102863
# rec.autos 102897
# rec.autos 103179
# rec.autos 103380
# rec.autos 103710
# rec.autos 103522
# rec.autos 101611
# rec.autos 103146
# rec.autos 103374
# rec.autos 103728
# rec.autos 102890
# rec.autos 101629
# rec.autos 102864
# rec.autos 103373
# rec.autos 101616
# rec.autos 103141
# rec.autos 103525
# rec.autos 103717
# rec.autos 103387
# rec.autos 103148
# rec.autos 102852
# rec.autos 103513
# rec.autos 103721
# rec.autos 103345
# rec.autos 102899
# rec.autos 103177
# rec.autos 101620
# rec.autos 103183
# rec.autos 102855
# rec.autos 103719
# rec.autos 101618
# rec.autos 103184
# rec.autos 103170
# rec.autos 101627
# rec.autos 103342
# rec.autos 103726
# rec.autos 103514
# rec.autos 103316
# rec.autos 101673
# rec.autos 103124
# rec.autos 103772
# rec.autos 102801
# rec.autos 103329
# rec.autos 103775
# rec.autos 101674
# rec.autos 103123
# rec.autos 103311
# rec.autos 101680
# rec.autos 102839
# rec.autos 103781
# rec.autos 102806
# rec.autos 103115
# rec.autos 101642
# rec.autos 103327
# rec.autos 103743
# rec.autos 103318
# rec.autos 102830
# rec.autos 102808
# rec.autos 103744
# rec.autos 103320
# rec.autos 103112
# rec.autos 101645
# rec.autos 102837
# rec.autos 103718
# rec.autos 101619
# rec.autos 102854
# rec.autos 103343
# rec.autos 103171
# rec.autos 101626
# rec.autos 103515
# rec.autos 103727
# rec.autos 103185
# rec.autos 102853
# rec.autos 103149
# rec.autos 103182
# rec.autos 103720
# rec.autos 103512
# rec.autos 103176
# rec.autos 102898
# rec.autos 101621
# rec.autos 103344
# rec.autos 102865
# rec.autos 103729
# rec.autos 102891
# rec.autos 101628
# rec.autos 103386
# rec.autos 101617
# rec.autos 103140
# rec.autos 103372
# rec.autos 103716
# rec.autos 103524
# rec.autos 103178
# rec.autos 102896
# rec.autos 102862
# rec.autos 103523
# rec.autos 103711
# rec.autos 103375
# rec.autos 101610
# rec.autos 103147
# rec.autos 103381
# rec.autos 103745
# rec.autos 103113
# rec.autos 101644
# rec.autos 103321
# rec.autos 102809
# rec.autos 102836
# rec.autos 103326
# rec.autos 103114
# rec.autos 101643
# rec.autos 103742
# rec.autos 102831
# rec.autos 103319
# rec.autos 101681
# rec.autos 102838
# rec.autos 103780
# rec.autos 103774
# rec.autos 103310
# rec.autos 101675
# rec.autos 103122
# rec.autos 102807
# rec.autos 101672
# rec.autos 103125
# rec.autos 103317
# rec.autos 103773
# rec.autos 103328
# rec.autos 102800
# rec.autos 102972
# rec.autos 103068
# rec.autos 102986
# rec.autos 103433
# rec.autos 103057
# rec.autos 103265
# rec.autos 102981
# rec.autos 102975
# rec.autos 103262
# rec.autos 103050
# rec.autos 103434
# rec.autos 103296
# rec.autos 103059
# rec.autos 102943
# rec.autos 103066
# rec.autos 102988
# rec.autos 103092
# rec.autos 103298
# rec.autos 102944
# rec.autos 103095
# rec.autos 103061
# rec.autos 103405
# rec.autos 102745
# rec.autos 103697
# rec.autos 103207
# rec.autos 103809
# rec.autos 103035
# rec.autos 103451
# rec.autos 103663
# rec.autos 102910
# rec.autos 103238
# rec.autos 103664
# rec.autos 103456
# rec.autos 103032
# rec.autos 103200
# rec.autos 101557
# rec.autos 102928
# rec.autos 102742
# rec.autos 103690
# rec.autos 101568
# rec.autos 102789
# rec.autos 102917
# rec.autos 103004
# rec.autos 101561
# rec.autos 103236
# rec.autos 102780
# rec.autos 103460
# rec.autos 102774
# rec.autos 103494
# rec.autos 101595
# rec.autos 103209
# rec.autos 103807
# rec.autos 102921
# rec.autos 103699
# rec.autos 101592
# rec.autos 102919
# rec.autos 103493
# rec.autos 102773
# rec.autos 102787
# rec.autos 101566
# rec.autos 103231
# rec.autos 103003
# rec.autos 102926
# rec.autos 101559
# rec.autos 103458
# rec.autos 102945
# rec.autos 103299
# rec.autos 103060
# rec.autos 103404
# rec.autos 103094
# rec.autos 102942
# rec.autos 103058
# rec.autos 103093
# rec.autos 102717
# rec.autos 103403
# rec.autos 102989
# rec.autos 103067
# rec.autos 102974
# rec.autos 102980
# rec.autos 103297
# rec.autos 103051
# rec.autos 103263
# rec.autos 103435
# rec.autos 102987
# rec.autos 103069
# rec.autos 102973
# rec.autos 103432
# rec.autos 103264
# rec.autos 103056
# rec.autos 102786
# rec.autos 103002
# rec.autos 101567
# rec.autos 103230
# rec.autos 102918
# rec.autos 101593
# rec.autos 102772
# rec.autos 103492
# rec.autos 101558
# rec.autos 103801
# rec.autos 103459
# rec.autos 102927
# rec.autos 103495
# rec.autos 102775
# rec.autos 101594
# rec.autos 101560
# rec.autos 103237
# rec.autos 103005
# rec.autos 103461
# rec.autos 103653
# rec.autos 102781
# rec.autos 102920
# rec.autos 103698
# rec.autos 103806
# rec.autos 103208
# rec.autos 102929
# rec.autos 102743
# rec.autos 103691
# rec.autos 103457
# rec.autos 103665
# rec.autos 103201
# rec.autos 101556
# rec.autos 103033
# rec.autos 102916
# rec.autos 101569
# rec.autos 102788
# rec.autos 103034
# rec.autos 103808
# rec.autos 103206
# rec.autos 101551
# rec.autos 103662
# rec.autos 103450
# rec.autos 102744
# rec.autos 103696
# rec.autos 103239
# rec.autos 102911
# comp.sys.mac.hardware 51832
# comp.sys.mac.hardware 51658
# comp.sys.mac.hardware 52029
# comp.sys.mac.hardware 51667
# comp.sys.mac.hardware 52224
# comp.sys.mac.hardware 52016
# comp.sys.mac.hardware 51693
# comp.sys.mac.hardware 51499
# comp.sys.mac.hardware 51835
# comp.sys.mac.hardware 52011
# comp.sys.mac.hardware 51694
# comp.sys.mac.hardware 52223
# comp.sys.mac.hardware 51660
# comp.sys.mac.hardware 52018
# comp.sys.mac.hardware 51803
# comp.sys.mac.hardware 51669
# comp.sys.mac.hardware 52443
# comp.sys.mac.hardware 52027
# comp.sys.mac.hardware 52215
# comp.sys.mac.hardware 50542
# comp.sys.mac.hardware 51656
# comp.sys.mac.hardware 51804
# comp.sys.mac.hardware 51651
# comp.sys.mac.hardware 52212
# comp.sys.mac.hardware 50545
# comp.sys.mac.hardware 51497
# comp.sys.mac.hardware 52020
# comp.sys.mac.hardware 52444
# comp.sys.mac.hardware 52080
# comp.sys.mac.hardware 51605
# comp.sys.mac.hardware 52074
# comp.sys.mac.hardware 50511
# comp.sys.mac.hardware 52246
# comp.sys.mac.hardware 51850
# comp.sys.mac.hardware 50516
# comp.sys.mac.hardware 52241
# comp.sys.mac.hardware 52073
# comp.sys.mac.hardware 52087
# comp.sys.mac.hardware 51602
# comp.sys.mac.hardware 51868
# comp.sys.mac.hardware 50529
# comp.sys.mac.hardware 51857
# comp.sys.mac.hardware 50520
# comp.sys.mac.hardware 52045
# comp.sys.mac.hardware 52283
# comp.sys.mac.hardware 51634
# comp.sys.mac.hardware 51895
# comp.sys.mac.hardware 52248
# comp.sys.mac.hardware 51861
# comp.sys.mac.hardware 51633
# comp.sys.mac.hardware 52284
# comp.sys.mac.hardware 51859
# comp.sys.mac.hardware 52042
# comp.sys.mac.hardware 52270
# comp.sys.mac.hardware 50527
# comp.sys.mac.hardware 51866
# comp.sys.mac.hardware 52089
# comp.sys.mac.hardware 50518
# comp.sys.mac.hardware 51892
# comp.sys.mac.hardware 51805
# comp.sys.mac.hardware 52021
# comp.sys.mac.hardware 52213
# comp.sys.mac.hardware 50544
# comp.sys.mac.hardware 51496
# comp.sys.mac.hardware 52445
# comp.sys.mac.hardware 51650
# comp.sys.mac.hardware 51802
# comp.sys.mac.hardware 51668
# comp.sys.mac.hardware 52019
# comp.sys.mac.hardware 51657
# comp.sys.mac.hardware 52442
# comp.sys.mac.hardware 52214
# comp.sys.mac.hardware 50543
# comp.sys.mac.hardware 52026
# comp.sys.mac.hardware 51834
# comp.sys.mac.hardware 51498
# comp.sys.mac.hardware 51661
# comp.sys.mac.hardware 52222
# comp.sys.mac.hardware 52010
# comp.sys.mac.hardware 51695
# comp.sys.mac.hardware 52028
# comp.sys.mac.hardware 51833
# comp.sys.mac.hardware 51659
# comp.sys.mac.hardware 52017
# comp.sys.mac.hardware 51692
# comp.sys.mac.hardware 52225
# comp.sys.mac.hardware 51666
# comp.sys.mac.hardware 52271
# comp.sys.mac.hardware 50526
# comp.sys.mac.hardware 52043
# comp.sys.mac.hardware 52285
# comp.sys.mac.hardware 51632
# comp.sys.mac.hardware 51858
# comp.sys.mac.hardware 50519
# comp.sys.mac.hardware 51893
# comp.sys.mac.hardware 51867
# comp.sys.mac.hardware 52088
# comp.sys.mac.hardware 51635
# comp.sys.mac.hardware 52044
# comp.sys.mac.hardware 52276
# comp.sys.mac.hardware 50521
# comp.sys.mac.hardware 51860
# comp.sys.mac.hardware 51894
# comp.sys.mac.hardware 52249
# comp.sys.mac.hardware 52086
# comp.sys.mac.hardware 51603
# comp.sys.mac.hardware 51869
# ...
# comp.sys.mac.hardware 51675
# comp.sys.mac.hardware 51681
# comp.sys.mac.hardware 52004
# comp.sys.mac.hardware 52236
# comp.sys.mac.hardware 51820
# comp.sys.mac.hardware 52209
# comp.sys.mac.hardware 52231
# comp.sys.mac.hardware 51686
# comp.sys.mac.hardware 52003
# comp.sys.mac.hardware 51672
# comp.sys.mac.hardware 51818
# comp.sys.mac.hardware 51827
# comp.sys.mac.hardware 52299
# comp.sys.mac.hardware 51844
# comp.sys.mac.hardware 51611
# comp.sys.mac.hardware 52094
# comp.sys.mac.hardware 52252
# comp.sys.mac.hardware 50505
# comp.sys.mac.hardware 52060
# comp.sys.mac.hardware 52404
# comp.sys.mac.hardware 52058
# comp.sys.mac.hardware 51843
# comp.sys.mac.hardware 51629
# comp.sys.mac.hardware 51888
# comp.sys.mac.hardware 52403
# comp.sys.mac.hardware 52067
# comp.sys.mac.hardware 52255
# comp.sys.mac.hardware 50502
# comp.sys.mac.hardware 51616
# comp.sys.mac.hardware 52093
# comp.sys.mac.hardware 51881
# comp.sys.mac.hardware 51875
# comp.sys.mac.hardware 52051
# comp.sys.mac.hardware 50534
# comp.sys.mac.hardware 52263
# comp.sys.mac.hardware 52435
# comp.sys.mac.hardware 51620
# comp.sys.mac.hardware 52297
# comp.sys.mac.hardware 51872
# comp.sys.mac.hardware 51618
# comp.sys.mac.hardware 52069
# comp.sys.mac.hardware 51886
# comp.sys.mac.hardware 52290
# comp.sys.mac.hardware 51627
# comp.sys.mac.hardware 50533
# comp.sys.mac.hardware 52264
# comp.sys.mac.hardware 52056
# comp.sys.mac.hardware 51673
# comp.sys.mac.hardware 51819
# comp.sys.mac.hardware 51687
# comp.sys.mac.hardware 52002
# comp.sys.mac.hardware 52230
# comp.sys.mac.hardware 51826
# comp.sys.mac.hardware 52237
# comp.sys.mac.hardware 51680
# comp.sys.mac.hardware 52005
# comp.sys.mac.hardware 51674
# comp.sys.mac.hardware 52208
# comp.sys.mac.hardware 51821
# comp.sys.mac.hardware 52201
# comp.sys.mac.hardware 52033
# comp.sys.mac.hardware 51642
# comp.sys.mac.hardware 51828
# comp.sys.mac.hardware 51689
# comp.sys.mac.hardware 51817
# comp.sys.mac.hardware 51645
# comp.sys.mac.hardware 52034
# comp.sys.mac.hardware 50551
# comp.sys.mac.hardware 52206
# comp.sys.mac.hardware 51810
# comp.sys.mac.hardware 52239
# comp.sys.mac.hardware 52070
# comp.sys.mac.hardware 50515
# comp.sys.mac.hardware 52242
# comp.sys.mac.hardware 52084
# comp.sys.mac.hardware 51601
# comp.sys.mac.hardware 51854
# comp.sys.mac.hardware 52289
# comp.sys.mac.hardware 52083
# comp.sys.mac.hardware 51606
# comp.sys.mac.hardware 50512
# comp.sys.mac.hardware 52245
# comp.sys.mac.hardware 52077
# comp.sys.mac.hardware 51898
# comp.sys.mac.hardware 51639
# comp.sys.mac.hardware 51853
# comp.sys.mac.hardware 52048
# comp.sys.mac.hardware 52287
# comp.sys.mac.hardware 51630
# comp.sys.mac.hardware 52273
# comp.sys.mac.hardware 50524
# comp.sys.mac.hardware 52041
# comp.sys.mac.hardware 51865
# comp.sys.mac.hardware 51891
# comp.sys.mac.hardware 52046
# comp.sys.mac.hardware 52274
# comp.sys.mac.hardware 50523
# comp.sys.mac.hardware 51637
# comp.sys.mac.hardware 51896
# comp.sys.mac.hardware 52079
# comp.sys.mac.hardware 51608
# comp.sys.mac.hardware 51862
# comp.sys.mac.hardware 50548
# comp.sys.mac.hardware 51836
# comp.sys.mac.hardware 52220
# comp.sys.mac.hardware 52012
# comp.sys.mac.hardware 51697
# comp.sys.mac.hardware 51809
# comp.sys.mac.hardware 51663
# comp.sys.mac.hardware 51831
# comp.sys.mac.hardware 52218
# comp.sys.mac.hardware 51664
# comp.sys.mac.hardware 52015
# comp.sys.mac.hardware 51690
# comp.sys.mac.hardware 52227
# comp.sys.mac.hardware 51807
# comp.sys.mac.hardware 51699
# comp.sys.mac.hardware 51838
# comp.sys.mac.hardware 51652
# comp.sys.mac.hardware 52023
# comp.sys.mac.hardware 52211
# comp.sys.mac.hardware 51494
# comp.sys.mac.hardware 50546
# comp.sys.mac.hardware 52229
# comp.sys.mac.hardware 51800
# comp.sys.mac.hardware 52440
# comp.sys.mac.hardware 52216
# comp.sys.mac.hardware 51493
# comp.sys.mac.hardware 50541
# comp.sys.mac.hardware 52024
# comp.sys.mac.hardware 51655
# comp.sys.mac.hardware 51636
# comp.sys.mac.hardware 52275
# comp.sys.mac.hardware 50522
# comp.sys.mac.hardware 52047
# comp.sys.mac.hardware 51609
# comp.sys.mac.hardware 51863
# comp.sys.mac.hardware 51897
# comp.sys.mac.hardware 52078
# comp.sys.mac.hardware 52040
# comp.sys.mac.hardware 52272
# comp.sys.mac.hardware 50525
# comp.sys.mac.hardware 51631
# comp.sys.mac.hardware 52286
# comp.sys.mac.hardware 51890
# comp.sys.mac.hardware 51864
# comp.sys.mac.hardware 52076
# comp.sys.mac.hardware 50513
# comp.sys.mac.hardware 52244
# comp.sys.mac.hardware 51899
# comp.sys.mac.hardware 52082
# comp.sys.mac.hardware 51607
# comp.sys.mac.hardware 52049
# comp.sys.mac.hardware 51638
# comp.sys.mac.hardware 51852
# comp.sys.mac.hardware 52085
# comp.sys.mac.hardware 51600
# comp.sys.mac.hardware 50514
# comp.sys.mac.hardware 52243
# comp.sys.mac.hardware 52071
# comp.sys.mac.hardware 51855
# comp.sys.mac.hardware 52288
# comp.sys.mac.hardware 51801
# comp.sys.mac.hardware 52228
# comp.sys.mac.hardware 51654
# comp.sys.mac.hardware 52441
# comp.sys.mac.hardware 52025
# comp.sys.mac.hardware 52217
# comp.sys.mac.hardware 51492
# comp.sys.mac.hardware 50540
# comp.sys.mac.hardware 51698
# comp.sys.mac.hardware 51806
# comp.sys.mac.hardware 52210
# comp.sys.mac.hardware 51495
# comp.sys.mac.hardware 50547
# comp.sys.mac.hardware 52022
# comp.sys.mac.hardware 52446
# comp.sys.mac.hardware 51839
# comp.sys.mac.hardware 51653
# comp.sys.mac.hardware 52219
# comp.sys.mac.hardware 51830
# comp.sys.mac.hardware 52226
# comp.sys.mac.hardware 52014
# comp.sys.mac.hardware 51691
# comp.sys.mac.hardware 51665
# comp.sys.mac.hardware 51837
# comp.sys.mac.hardware 50549
# comp.sys.mac.hardware 51808
# comp.sys.mac.hardware 51662
# comp.sys.mac.hardware 52013
# comp.sys.mac.hardware 52221
# comp.sys.mac.hardware 52161
# comp.sys.mac.hardware 51710
# comp.sys.mac.hardware 51522
# comp.sys.mac.hardware 51945
# comp.sys.mac.hardware 51525
# comp.sys.mac.hardware 52192
# comp.sys.mac.hardware 51717
# comp.sys.mac.hardware 52166
# comp.sys.mac.hardware 51989
# comp.sys.mac.hardware 51728
# comp.sys.mac.hardware 51942
# comp.sys.mac.hardware 52159
# comp.sys.mac.hardware 51513
# comp.sys.mac.hardware 51721
# comp.sys.mac.hardware 50435
# comp.sys.mac.hardware 52150
# comp.sys.mac.hardware 51974
# comp.sys.mac.hardware 51980
# comp.sys.mac.hardware 52157
# comp.sys.mac.hardware 50432
# comp.sys.mac.hardware 51726
# comp.sys.mac.hardware 51514
# comp.sys.mac.hardware 51987
# comp.sys.mac.hardware 52168
# comp.sys.mac.hardware 51719
# comp.sys.mac.hardware 51973
# comp.sys.mac.hardware 50459
# comp.sys.mac.hardware 51927
# comp.sys.mac.hardware 50466
# comp.sys.mac.hardware 52331
# comp.sys.mac.hardware 52103
# comp.sys.mac.hardware 51786
# comp.sys.mac.hardware 51918
# comp.sys.mac.hardware 51540
# comp.sys.mac.hardware 50492
# comp.sys.mac.hardware 51772
# comp.sys.mac.hardware 51920
# comp.sys.mac.hardware 51578
# comp.sys.mac.hardware 52309
# comp.sys.mac.hardware 51775
# comp.sys.mac.hardware 51547
# comp.sys.mac.hardware 50495
# comp.sys.mac.hardware 52104
# comp.sys.mac.hardware 51781
# comp.sys.mac.hardware 50461
# comp.sys.mac.hardware 52336
# comp.sys.mac.hardware 51916
# comp.sys.mac.hardware 50468
# comp.sys.mac.hardware 51788
# comp.sys.mac.hardware 51929
# comp.sys.mac.hardware 51743
# comp.sys.mac.hardware 51571
# comp.sys.mac.hardware 52132
# comp.sys.mac.hardware 52300
# comp.sys.mac.hardware 50457
# comp.sys.mac.hardware 51585
# comp.sys.mac.hardware 52338
# comp.sys.mac.hardware 51911
# comp.sys.mac.hardware 51549
# comp.sys.mac.hardware 52307
# comp.sys.mac.hardware 50450
# comp.sys.mac.hardware 51582
# comp.sys.mac.hardware 52135
# comp.sys.mac.hardware 51576
# comp.sys.mac.hardware 51744
# comp.sys.mac.hardware 51515
# comp.sys.mac.hardware 51727
# comp.sys.mac.hardware 50433
# comp.sys.mac.hardware 52156
# comp.sys.mac.hardware 51718
# comp.sys.mac.hardware 51972
# comp.sys.mac.hardware 51986
# comp.sys.mac.hardware 52169
# comp.sys.mac.hardware 52151
# comp.sys.mac.hardware 50434
# comp.sys.mac.hardware 51720
# comp.sys.mac.hardware 51512
# comp.sys.mac.hardware 51981
# comp.sys.mac.hardware 51975
# comp.sys.mac.hardware 52167
# comp.sys.mac.hardware 51988
# comp.sys.mac.hardware 52193
# comp.sys.mac.hardware 51716
# comp.sys.mac.hardware 51524
# comp.sys.mac.hardware 52158
# comp.sys.mac.hardware 51729
# comp.sys.mac.hardware 51943
# comp.sys.mac.hardware 51523
# comp.sys.mac.hardware 52194
# comp.sys.mac.hardware 51711
# comp.sys.mac.hardware 52160
# comp.sys.mac.hardware 51944
# comp.sys.mac.hardware 51910
# comp.sys.mac.hardware 51548
# comp.sys.mac.hardware 52339
# comp.sys.mac.hardware 51745
# comp.sys.mac.hardware 51577
# comp.sys.mac.hardware 52134
# comp.sys.mac.hardware 52306
# comp.sys.mac.hardware 50451
# comp.sys.mac.hardware 51583
# comp.sys.mac.hardware 51789
# comp.sys.mac.hardware 50469
# comp.sys.mac.hardware 51917
# comp.sys.mac.hardware 52301
# comp.sys.mac.hardware 50456
# comp.sys.mac.hardware 51584
# comp.sys.mac.hardware 52133
# comp.sys.mac.hardware 51928
# comp.sys.mac.hardware 51570
# comp.sys.mac.hardware 51742
# comp.sys.mac.hardware 52308
# comp.sys.mac.hardware 51921
# comp.sys.mac.hardware 51579
# comp.sys.mac.hardware 50460
# comp.sys.mac.hardware 52337
# comp.sys.mac.hardware 52105
# comp.sys.mac.hardware 51780
# comp.sys.mac.hardware 51546
# comp.sys.mac.hardware 50494
# comp.sys.mac.hardware 51774
# comp.sys.mac.hardware 51926
# comp.sys.mac.hardware 50458
# comp.sys.mac.hardware 51919
# comp.sys.mac.hardware 51773
# comp.sys.mac.hardware 51541
# comp.sys.mac.hardware 50493
# comp.sys.mac.hardware 52102
# comp.sys.mac.hardware 51787
# comp.sys.mac.hardware 50467
# comp.sys.mac.hardware 52330
# comp.sys.mac.hardware 51563
# comp.sys.mac.hardware 51751
# comp.sys.mac.hardware 50445
# comp.sys.mac.hardware 51597
# comp.sys.mac.hardware 52312
# comp.sys.mac.hardware 52120
# comp.sys.mac.hardware 51904
# comp.sys.mac.hardware 52127
# comp.sys.mac.hardware 50442
# comp.sys.mac.hardware 51590
# comp.sys.mac.hardware 52315
# comp.sys.mac.hardware 51756
# comp.sys.mac.hardware 51564
# comp.sys.mac.hardware 52118
# comp.sys.mac.hardware 50489
# comp.sys.mac.hardware 51769
# comp.sys.mac.hardware 51903
# comp.sys.mac.hardware 51794
# comp.sys.mac.hardware 52111
# comp.sys.mac.hardware 52323
# comp.sys.mac.hardware 50474
# comp.sys.mac.hardware 51760
# comp.sys.mac.hardware 51552
# comp.sys.mac.hardware 50480
# comp.sys.mac.hardware 51599
# comp.sys.mac.hardware 51935
# comp.sys.mac.hardware 51555
# comp.sys.mac.hardware 50487
# comp.sys.mac.hardware 51767
# comp.sys.mac.hardware 52324
# comp.sys.mac.hardware 50473
# comp.sys.mac.hardware 51793
# comp.sys.mac.hardware 52116
# comp.sys.mac.hardware 51758
# comp.sys.mac.hardware 51932
# comp.sys.mac.hardware 52129
# comp.sys.mac.hardware 52189
# comp.sys.mac.hardware 51966
# comp.sys.mac.hardware 51992
# comp.sys.mac.hardware 50418
# comp.sys.mac.hardware 51959
# comp.sys.mac.hardware 51733
# comp.sys.mac.hardware 51501
# comp.sys.mac.hardware 52142
# comp.sys.mac.hardware 50427
# comp.sys.mac.hardware 51995
# comp.sys.mac.hardware 51961
# comp.sys.mac.hardware 51539
# comp.sys.mac.hardware 50420
# comp.sys.mac.hardware 52145
# comp.sys.mac.hardware 51506
# comp.sys.mac.hardware 51734
# comp.sys.mac.hardware 51957
# comp.sys.mac.hardware 52341
# comp.sys.mac.hardware 52173
# comp.sys.mac.hardware 51968
# comp.sys.mac.hardware 51530
# comp.sys.mac.hardware 51702
# comp.sys.mac.hardware 52187
# comp.sys.mac.hardware 51950
# comp.sys.mac.hardware 51508
# comp.sys.mac.hardware 51705
# comp.sys.mac.hardware 52180
# comp.sys.mac.hardware 51537
# comp.sys.mac.hardware 52174
# comp.sys.mac.hardware 52346
# comp.sys.mac.hardware 51792
# comp.sys.mac.hardware 52117
# comp.sys.mac.hardware 52325
# comp.sys.mac.hardware 50472
# comp.sys.mac.hardware 51766
# comp.sys.mac.hardware 51554
# comp.sys.mac.hardware 50486
# comp.sys.mac.hardware 52128
# comp.sys.mac.hardware 51759
# comp.sys.mac.hardware 51933
# comp.sys.mac.hardware 51553
# comp.sys.mac.hardware 51761
# comp.sys.mac.hardware 52322
# comp.sys.mac.hardware 50475
# comp.sys.mac.hardware 51795
# comp.sys.mac.hardware 52110
# comp.sys.mac.hardware 51934
# comp.sys.mac.hardware 51598
# comp.sys.mac.hardware 51565
# comp.sys.mac.hardware 51757
# comp.sys.mac.hardware 50443
# comp.sys.mac.hardware 51591
# comp.sys.mac.hardware 52314
# comp.sys.mac.hardware 52126
# comp.sys.mac.hardware 51768
# comp.sys.mac.hardware 50488
# comp.sys.mac.hardware 51902
# comp.sys.mac.hardware 52119
# comp.sys.mac.hardware 52121
# comp.sys.mac.hardware 50444
# comp.sys.mac.hardware 51596
# comp.sys.mac.hardware 52313
# comp.sys.mac.hardware 51750
# comp.sys.mac.hardware 51562
# comp.sys.mac.hardware 51905
# comp.sys.mac.hardware 51951
# comp.sys.mac.hardware 51509
# comp.sys.mac.hardware 52347
# comp.sys.mac.hardware 52175
# comp.sys.mac.hardware 51536
# comp.sys.mac.hardware 51704
# comp.sys.mac.hardware 52181
# comp.sys.mac.hardware 51956
# comp.sys.mac.hardware 50428
# comp.sys.mac.hardware 51969
# comp.sys.mac.hardware 51703
# comp.sys.mac.hardware 52186
# comp.sys.mac.hardware 51531
# comp.sys.mac.hardware 52172
# comp.sys.mac.hardware 52340
# comp.sys.mac.hardware 51960
# comp.sys.mac.hardware 51538
# comp.sys.mac.hardware 51994
# comp.sys.mac.hardware 51735
# comp.sys.mac.hardware 51507
# comp.sys.mac.hardware 52144
# comp.sys.mac.hardware 50421
# comp.sys.mac.hardware 51993
# comp.sys.mac.hardware 50419
# comp.sys.mac.hardware 52188
# comp.sys.mac.hardware 51967
# comp.sys.mac.hardware 50426
# comp.sys.mac.hardware 52143
# comp.sys.mac.hardware 51958
# comp.sys.mac.hardware 51500
# comp.sys.mac.hardware 51732
# comp.sys.mac.hardware 51640
# comp.sys.mac.hardware 52203
# comp.sys.mac.hardware 52031
# comp.sys.mac.hardware 51815
# comp.sys.mac.hardware 52036
# comp.sys.mac.hardware 52204
# comp.sys.mac.hardware 51647
# comp.sys.mac.hardware 52009
# comp.sys.mac.hardware 51678
# comp.sys.mac.hardware 51812
# comp.sys.mac.hardware 51685
# comp.sys.mac.hardware 52000
# comp.sys.mac.hardware 52232
# comp.sys.mac.hardware 51671
# comp.sys.mac.hardware 51824
# comp.sys.mac.hardware 51676
# comp.sys.mac.hardware 52235
# comp.sys.mac.hardware 51682
# comp.sys.mac.hardware 52007
# comp.sys.mac.hardware 51649
# comp.sys.mac.hardware 51823
# comp.sys.mac.hardware 52038
# comp.sys.mac.hardware 52098
# comp.sys.mac.hardware 51877
# comp.sys.mac.hardware 51883
# comp.sys.mac.hardware 50509
# comp.sys.mac.hardware 51848
# comp.sys.mac.hardware 51622
# comp.sys.mac.hardware 52295
# comp.sys.mac.hardware 52053
# comp.sys.mac.hardware 50536
# comp.sys.mac.hardware 52261
# comp.sys.mac.hardware 52437
# comp.sys.mac.hardware 52259
# comp.sys.mac.hardware 51884
# comp.sys.mac.hardware 51870
# comp.sys.mac.hardware 50531
# comp.sys.mac.hardware 52266
# comp.sys.mac.hardware 52054
# comp.sys.mac.hardware 52292
# comp.sys.mac.hardware 51625
# comp.sys.mac.hardware 52439
# comp.sys.mac.hardware 50538
# comp.sys.mac.hardware 51846
# comp.sys.mac.hardware 52250
# comp.sys.mac.hardware 50507
# comp.sys.mac.hardware 52062
# comp.sys.mac.hardware 52406
# comp.sys.mac.hardware 51879
# comp.sys.mac.hardware 51613
# comp.sys.mac.hardware 52096
# comp.sys.mac.hardware 51841
# comp.sys.mac.hardware 52268
# comp.sys.mac.hardware 51614
# comp.sys.mac.hardware 52091
# comp.sys.mac.hardware 52065
# comp.sys.mac.hardware 52257
# comp.sys.mac.hardware 50500
# comp.sys.mac.hardware 51683
# comp.sys.mac.hardware 52006
# comp.sys.mac.hardware 52234
# comp.sys.mac.hardware 51677
# comp.sys.mac.hardware 52039
# comp.sys.mac.hardware 51648
# comp.sys.mac.hardware 51822
# comp.sys.mac.hardware 51670
# comp.sys.mac.hardware 52233
# comp.sys.mac.hardware 51684
# comp.sys.mac.hardware 52001
# comp.sys.mac.hardware 51825
# comp.sys.mac.hardware 51646
# comp.sys.mac.hardware 50552
# comp.sys.mac.hardware 52205
# comp.sys.mac.hardware 52037
# comp.sys.mac.hardware 51679
# comp.sys.mac.hardware 51813
# comp.sys.mac.hardware 52008
# comp.sys.mac.hardware 52030
# comp.sys.mac.hardware 52202
# comp.sys.mac.hardware 51641
# comp.sys.mac.hardware 51814
# comp.sys.mac.hardware 52269
# comp.sys.mac.hardware 51840
# comp.sys.mac.hardware 52256
# comp.sys.mac.hardware 50501
# comp.sys.mac.hardware 52064
# comp.sys.mac.hardware 51615
# comp.sys.mac.hardware 52090
# comp.sys.mac.hardware 51847
# comp.sys.mac.hardware 52438
# comp.sys.mac.hardware 50539
# comp.sys.mac.hardware 51878
# comp.sys.mac.hardware 51612
# comp.sys.mac.hardware 52097
# comp.sys.mac.hardware 52063
# comp.sys.mac.hardware 52251
# comp.sys.mac.hardware 50506
# comp.sys.mac.hardware 52407
# comp.sys.mac.hardware 51871
# comp.sys.mac.hardware 52258
# comp.sys.mac.hardware 51885
# comp.sys.mac.hardware 51624
# comp.sys.mac.hardware 52293
# comp.sys.mac.hardware 52055
# comp.sys.mac.hardware 50530
# comp.sys.mac.hardware 52267
# comp.sys.mac.hardware 51882
# comp.sys.mac.hardware 50508
# comp.sys.mac.hardware 52099
# comp.sys.mac.hardware 51876
# comp.sys.mac.hardware 50537
# comp.sys.mac.hardware 52260
# comp.sys.mac.hardware 52052
# comp.sys.mac.hardware 52436
# comp.sys.mac.hardware 51849
# comp.sys.mac.hardware 52294
# comp.sys.mac.hardware 51623

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=0)

# %%
# A list of common english words which should not affect predictions
stopwords = ['a', 'about', 'above', 'across', 'after', 'afterwards', 'again', 'against', 'all', 'almost', 'alone',
             'along', 'already', 'also', 'although', 'always', 'am', 'among', 'amongst', 'amoungst', 'amount',
             'an', 'and', 'another', 'any', 'anyhow', 'anyone', 'anything', 'anyway', 'anywhere', 'are', 'around',
             'as', 'at', 'back', 'be', 'became', 'because', 'become', 'becomes', 'becoming', 'been', 'before',
             'beforehand', 'behind', 'being', 'below', 'beside', 'besides', 'between', 'beyond', 'bill', 'both',
             'bottom', 'but', 'by', 'call', 'can', 'cannot', 'cant', 'co', 'con', 'could', 'couldnt', 'cry', 'de',
             'describe', 'detail', 'did', 'do', 'does', 'doing', 'don', 'done', 'down', 'due', 'during', 'each', 'eg',
             'eight', 'either', 'eleven', 'else', 'elsewhere', 'empty', 'enough', 'etc', 'even', 'ever', 'every', 'everyone',
             'everything', 'everywhere', 'except', 'few', 'fifteen', 'fify', 'fill', 'find', 'fire', 'first', 'five', 'for',
             'former', 'formerly', 'forty', 'found', 'four', 'from', 'front', 'full', 'further', 'get', 'give', 'go', 'had',
             'has', 'hasnt', 'have', 'having', 'he', 'hence', 'her', 'here', 'hereafter', 'hereby', 'herein', 'hereupon',
             'hers', 'herself', 'him', 'himself', 'his', 'how', 'however', 'hundred', 'i', 'ie', 'if', 'in', 'inc', 'indeed',
             'interest', 'into', 'is', 'it', 'its', 'itself', 'just', 'keep', 'last', 'latter', 'latterly', 'least', 'less',
             'ltd', 'made', 'many', 'may', 'me', 'meanwhile', 'might', 'mill', 'mine', 'more', 'moreover', 'most', 'mostly',
             'move', 'much', 'must', 'my', 'myself', 'name', 'namely', 'neither', 'never', 'nevertheless', 'next', 'nine',
             'no', 'nobody', 'none', 'noone', 'nor', 'not', 'nothing', 'now', 'nowhere', 'of', 'off', 'often', 'on', 'once',
             'one', 'only', 'onto', 'or', 'other', 'others', 'otherwise', 'our', 'ours', 'ourselves', 'out', 'over', 'own',
             'part', 'per', 'perhaps', 'please', 'put', 'rather', 're', 's', 'same', 'see', 'seem', 'seemed', 'seeming',
             'seems', 'serious', 'several', 'she', 'should', 'show', 'side', 'since', 'sincere', 'six', 'sixty', 'so', 
             'some', 'somehow', 'someone', 'something', 'sometime', 'sometimes', 'somewhere', 'still', 'such', 'system',
             't', 'take', 'ten', 'than', 'that', 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'thence', 'there',
             'thereafter', 'thereby', 'therefore', 'therein', 'thereupon', 'these', 'they', 'thickv', 'thin', 'third', 'this',
             'those', 'though', 'three', 'through', 'throughout', 'thru', 'thus', 'to', 'together', 'too', 'top', 'toward',
             'towards', 'twelve', 'twenty', 'two', 'un', 'under', 'until', 'up', 'upon', 'us', 'very', 'via', 'was', 'we',
             'well', 'were', 'what', 'whatever', 'when', 'whence', 'whenever', 'where', 'whereafter', 'whereas', 'whereby',
             'wherein', 'whereupon', 'wherever', 'whether', 'which', 'while', 'whither', 'who', 'whoever', 'whole', 'whom',
             'whose', 'why', 'will', 'with', 'within', 'without', 'would', 'yet', 'you', 'your', 'yours', 'yourself',
             'yourselves']

# %%
# Building a vocabulary of words from the given documents
vocab = {}
for i in range(len(X_train)):
    word_list = []
    for word in X_train[i][1].split():
        word_new  = word.strip(string.punctuation).lower()
        if (len(word_new)>2)  and (word_new not in stopwords):  
            if word_new in vocab:
                vocab[word_new]+=1
            else:
                vocab[word_new]=1

# %%
# keep only the words with more than 50 word counts
features = []
for key in vocab:
    if vocab[key] >=50:
        features.append(key)

# %%
# To represent training data as word vector counts
X_train_dataset = np.zeros((len(X_train),len(features)))
# This can take some time to complete
for i in range(len(X_train)):
    # print(i) # Uncomment to see progress
    word_list = [ word.strip(string.punctuation).lower() for word in X_train[i][1].split()]
    for word in word_list:
        if word in features:
            X_train_dataset[i][features.index(word)] += 1

# %%
# To represent test data as word vector counts
X_test_dataset = np.zeros((len(X_test),len(features)))
# This can take some time to complete
for i in range(len(X_test)):
    # print(i) # Uncomment to see progress
    word_list = [ word.strip(string.punctuation).lower() for word in X_test[i][1].split()]
    for word in word_list:
        if word in features:
            X_test_dataset[i][features.index(word)] += 1

# %%
# Implementing Multinomial Naive Bayes from scratch
class MultinomialNaiveBayes:
    
    def __init__(self):
        # count is a dictionary which stores several dictionaries corresponding to each news category
        # each value in the subdictionary represents the freq of the key corresponding to that news category 
        self.count = {}
        # classes represents the different news categories
        self.classes = None
    
    def fit(self,X_train,Y_train):
        # This can take some time to complete       
        self.classes = set(Y_train)
        for class_ in self.classes:
            self.count[class_] = {}
            for i in range(len(X_train[0])):
                self.count[class_][i] = 0
            self.count[class_]['total'] = 0
        self.count['total_points'] = len(X_train)
        
        for i in range(len(X_train)):
            for j in range(len(X_train[0])):
                self.count[Y_train[i]][j]+=X_train[i][j]
            self.count[Y_train[i]]['total']+=1
    
    def __probability(self,test_point,class_):
        
        log_prob = np.log(self.count[class_]['total']) - np.log(self.count['total_points'])
        total_words = len(test_point)
        for i in range(len(test_point)):
            current_word_prob = test_point[i]*(np.log(self.count[class_][i]+1)-np.log(self.count[class_]['total']+total_words))
            log_prob += current_word_prob
        
        return log_prob
    
    
    def __predictSinglePoint(self,test_point):
        
        best_class = None
        best_prob = None
        first_run = True
        
        for class_ in self.classes:
            log_probability_current_class = self.__probability(test_point,class_)
            if (first_run) or (log_probability_current_class > best_prob) :
                best_class = class_
                best_prob = log_probability_current_class
                first_run = False
                
        return best_class
        
  
    def predict(self,X_test):
        # This can take some time to complete
        Y_pred = [] 
        for i in range(len(X_test)):
        # print(i) # Uncomment to see progress
            Y_pred.append( self.__predictSinglePoint(X_test[i]) )
        
        return Y_pred
    
    def score(self,Y_pred,Y_true):
        # returns the mean accuracy
        count = 0
        for i in range(len(Y_pred)):
            if Y_pred[i] == Y_true[i]:
                count+=1
        return count/len(Y_pred)

# %%
clf2 = MultinomialNaiveBayes()
clf2.fit(X_train_dataset,Y_train)
Y_test_pred = clf2.predict(X_test_dataset)
our_score_test = clf2.score(Y_test_pred,Y_test)  
print("Our score on testing data :",our_score_test)
print("Classification report for testing data :-")
print(classification_report(Y_test, Y_test_pred))
# Out:
# Our score on testing data : 0.9329758713136729
# Classification report for testing data :-
#                        precision    recall  f1-score   support
#
# comp.sys.mac.hardware       1.00      0.94      0.97       239
#             rec.autos       0.99      0.85      0.91       234
# talk.politics.mideast       0.85      1.00      0.92       273
#
#             micro avg       0.93      0.93      0.93       746
#             macro avg       0.95      0.93      0.93       746
#          weighted avg       0.94      0.93      0.93       746

# %%
print("Score of our model on test data:",our_score_test)
print("Score of inbuilt sklearn's MultinomialNB on the same data :",sklearn_score_test)
